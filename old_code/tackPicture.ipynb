# %%
from Modbus_DW import *
from camera import *

# %%
c=connectRobot()
# c=connectRobot(SERVER_HOST = "192.168.1.1")
# Out:
# connect success
# DRA is runing now

# %%
pos=getRobotP(c)
print(pos)
# takePicture("11_29")
# Out:
# read try: 0
# [290.0, -11.941, 559.999, -180.0, 0.0, 0.0]

# %%
# pos=getRobotP(c)
# print(pos)
# saveRobotP(pos)
# robotP=[]
# robotP.append(pos)

# %%
pos=[290.0, -11.941, 560.0, -180.0, 0.0, 0.0]
print(pos)
teachPoint(c,pos)
print("run finish")
# teachPoint(c,robotP[0])
pos=getRobotP(c)
print(pos)
# takePicture("pic3")
# Out:
# [290.0, -11.941, 560.0, -180.0, 0.0, 0.0]
# wait for move 0
# wait for move 1
# wait for move 2
# run finish
# read try: 0
# [289.999, -11.941, 559.999, -180.0, 0.0, 0.0]

# %%
# pos=getRobotP(c)
pos=[290.0, -11.941, 560.0, -180.0, 0.0, 0.0]
print(pos)
makeCamset(c,path="picture/11_29_2",p0=pos)   
# teachPoint(c,pos)
# Out:
# [290.0, -11.941, 560.0, -180.0, 0.0, 0.0]
# wait for move 0
# wait for move 1
# read try: 0
# [289.999, -11.941, 559.999, -180.0, 0.0, 0.0]
# 目錄不存在。建一個目錄...
# 內有: 0 對圖片
# start camera:
# 目錄不存在。建一個目錄...
# wait for move 0
# wait for move 1
# wait for move 2
# wait for move 3
# read try: 0
# read try: 1
# [299.999, -11.941, 559.999, -180.0, 0.0, 0.0]
# 目錄存在。
# 內有: 1 對圖片
# start camera:
# 目錄存在。
# wait for move 0
# wait for move 1
# wait for move 2
# wait for move 3
# read try: 0
# read try: 1
# [290.0, -31.94, 559.999, -180.0, 0.0, 15.0]
# 目錄存在。
# 內有: 2 對圖片
# start camera:
# 目錄存在。
# wait for move 0
# wait for move 1
# wait for move 2
# wait for move 3
# read try: 0
# [289.999, 8.057, 559.999, -180.0, 0.0, -15.0]
# 目錄存在。
# 內有: 3 對圖片
# start camera:
# 目錄存在。
# wait for move 0
# wait for move 1
# wait for move 2
# wait for move 3
# read try: 0
# [289.999, -1.94, 559.999, -180.0, 0.0, 0.0]
# 目錄存在。
# 內有: 4 對圖片
# start camera:
# 目錄存在。
# wait for move 0
# wait for move 1
# wait for move 2
# ...

# %%
# pos=getRobotP(c)
# print(pos)

# %%
# Out:
# [437.195, -50.004, 570.37, 177.131, -1.512, -2.359]
# 目錄存在。
# 內有: 0 對圖片
# start camera:
# 目錄存在。
# [447.195, -50.004, 570.37, 177.132, -1.512, -2.358]
# 目錄存在。
# 內有: 1 對圖片
# start camera:
# 目錄存在。
# [447.195, -40.007, 570.37, 177.132, -1.512, -2.359]
# 目錄存在。
# 內有: 2 對圖片
# start camera:
# 目錄存在。
# [447.195, -40.005, 580.37, 177.132, -1.512, -2.359]
# 目錄存在。
# 內有: 3 對圖片
# start camera:
# 目錄存在。
# [447.195, -70.004, 580.37, -172.868, -1.512, -2.359]
# 目錄存在。
# 內有: 4 對圖片
# start camera:
# 目錄存在。
# [447.195, -100.004, 580.37, -172.868, -1.512, -2.359]
# 目錄存在。
# 內有: 5 對圖片
# start camera:
# 目錄存在。
# [447.195, -20.006, 580.37, 167.132, -1.512, -2.359]
# 目錄存在。
# 內有: 6 對圖片
# start camera:
# 目錄存在。
# [447.195, 19.993, 580.37, 167.132, -1.512, -2.359]
# 目錄存在。
# 內有: 7 對圖片
# start camera:
# 目錄存在。
# [487.195, -50.003, 570.37, 177.132, 8.488, -2.359]
# 目錄存在。
# 內有: 8 對圖片
# start camera:
# 目錄存在。
# [487.195, -30.007, 570.37, 177.132, 8.488, -2.359]
# 目錄存在。
# 內有: 9 對圖片
# start camera:
# 目錄存在。
# ...

# %%
closeRobot(c)
